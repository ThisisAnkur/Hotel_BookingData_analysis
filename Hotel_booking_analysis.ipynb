# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## About Dataset :-
# #### Content :
#     This data set contains booking information for a city hotel and a resort hotel, and includes information such as when       the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available           parking spaces, among other things.
#
#     All personally identifiable information has been removed from the data.
#
#     This data is from Nuno Antonio, Ana Almeida, and Luis Nunes from their February 2019 article, “Hotel Booking Demand         Datasets,” written for their Brief Volume 22 for his Data.

# %% [markdown]
# ##  Import packages & read data.
#     We will import these packages and libraries to analyze and visualize data:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('hotel_bookings.csv')

# %%
# make sure all columns are displayed
pd.options.display.max_columns=32

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %% [markdown]
# # Columns description
#     1. hotel
#         Hotel (H1 = Resort Hotel or H2 = City Hotel)
#
#     2. is_canceled
#         Value indicating if the booking was canceled (1) or not (0)
#
#     3. lead_time
#         Number of days that elapsed between the entering date of the booking into the PMS and the arrival date
#         arrival_date_year
#
#     4. arrival_date_year
#         Year of arrival date
#
#     5. arrival_date_month
#         month of arrival date
#
#     6. arrival_date_week_number
#         Week number of year for arrival date
#
#     7. arrival_date_day_of_month
#         Day of arrival date
#
#     8. stays_in_weekend_nights
#         Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
#     9. stays_in_week_nights
#         Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
#      10. adults
#             Number of adults
#
#     11. children
#          Number of children
#
#     12. babies
#          Number of babies
#
#     13. meal
#          Type of meal booked. Categories are presented in standard hospitality meal packages: Undefined/SC – no meal                  package; BB – Bed & Breakfast; HB – Half board (breakfast and one other meal – usually dinner); FB – Full                  board (breakfast,   lunch and dinner)
#
#     14. country
#          Country of origin. Categories are represented in the ISO 3155–3:2013 format
#
#     15. market_segment
#          Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
#     16. distribution_channel
#           Booking distribution channel.
#           The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
#     17. is_repeated_guest
#          Value indicating if the booking name was from a repeated guest (1) or not (0)
#
#     18. previous_cancellations
#          Number of previous bookings that were cancelled by the customer prior to the current booking
#
#     19. previous_bookings_not_canceled
#          Number of previous bookings not cancelled by the customer prior to the current booking
#
#     20. reserved_room_type
#          Code of room type reserved. Code is presented instead of designation for anonymity reasons.
#
#     21. assigned_room_type
#          Code for the type of room assigned to the booking. Sometimes the assigned room type differs from the reserved room          type due to hotel operation reasons (e.g. overbooking) or by customer request. Code is presented instead of                designation for anonymity reasons.
#
#     22. booking_changes
#          Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the               moment of check-in or cancellation
#
#     23. deposit_type
#          Indication on if the customer made a deposit to guarantee the booking. This variable can assume three categories:           No Deposit – no deposit was made; Non Refund – a deposit was made in the value of the total stay cost; Refundable            –         a deposit was made with a value under the total cost of stay.
#
#     24. agent
#          ID of the travel agency that made the booking
#
#     25. company
#          ID of the company/entity that made the booking or responsible for paying the booking. ID is presented instead of            designation for anonymity reasons
#
#     26. days_in_waiting_list
#          Number of days the booking was in the waiting list before it was confirmed to the customer
#
#     27. customer_type
#                Type of booking, assuming one of four categories: Contract - when the booking has an allotment or other type                of  contract associated to it; Group – when the booking is associated to a group; Transient – when the                      booking is not part of a group or contract, and is not associated to other transient booking; Transient-                    party – when the booking is transient, but is associated to at least other transient booking
#
#     28. adr
#         Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
#         required_car_parking_spaces
#
#     29. required_car_parking_spaces
#          Number of car parking spaces required by the customer
#
#     30. total_of_special_requests
#          Number of special requests made by the customer (e.g. twin bed or high floor)
#          reservation_status
#
#     31. reservation_status
#          Reservation last status, assuming one of three categories: Canceled – booking was canceled by the customer; Check-          Out – customer has checked in but already departed; No-Show – customer did not check-in and did inform the hotel            of         the reason why
#
#     32. reservation_status_date
#          Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to

# %% [markdown]
# ## Data Preparation
# #### Handle missing values

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
for i in df.columns:
    if df[i].isna().sum() != 0:
        print('null values in', i, 'column :', df[i].isna().sum()) 
        print('percentage of missing value in ', i,df[i].isnull().sum()*100/df.shape[0],"%")
# Out:
# null values in children column : 4
# percentage of missing value in  children 0.0033503643521232934 %
# null values in country column : 488
# percentage of missing value in  country 0.40874445095904177 %
# null values in agent column : 16340
# percentage of missing value in  agent 13.686238378423653 %
# null values in company column : 112593
# percentage of missing value in  company 94.30689337465449 %

# %% [markdown]
# So we have 4 columns with null values. We need to understand the context of the data to make a decision on how to handle these null values. Here is how I handled it:

# %%
# 94% of rows in company columns are null so we have only 1 option is drop it.
df = df.drop(columns='company')

# We can drop 4 rows containing null values from chidren column
# It will not affect our result too much
df = df.dropna(subset = ['children'])


# For country we will fill missing values with the mode frequent value.
df['country'].fillna(df['country'].mode()[0], inplace= True)

#lastly, for agent column will will fill 9 for every null values. 
# this will represent agent ID 
df['agent'].fillna(0, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119386 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119386 non-null  object
#  1   is_canceled                     119386 non-null  int64
#  2   lead_time                       119386 non-null  int64
#  3   arrival_date_year               119386 non-null  int64
#  4   arrival_date_month              119386 non-null  object
#  5   arrival_date_week_number        119386 non-null  int64
#  6   arrival_date_day_of_month       119386 non-null  int64
#  7   stays_in_weekend_nights         119386 non-null  int64
#  8   stays_in_week_nights            119386 non-null  int64
#  9   adults                          119386 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119386 non-null  int64
# ...

# %%
df.duplicated().sum()
# Out:
# 32020

# %% [markdown]
# ## Handle duplicates value
# We run below code to figure out the number of duplicated rows. We will remove them because it is very unlikely to to have 2 similar rows. It means we assume that there no 2 booking with similar number of people, date, channel, agent, number of requirements, and booking history.
#
# We can just drop those duplicated columns:

# %%
df.drop_duplicates(inplace =True)

# %% [markdown]
# ## Changing datatypes
# We spot some columns still in string types, let s modify it:

# %%
df['children'] = df['children'].astype(int)
df['agent'] = df['agent'].astype(int)
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
for col in df.describe(include= 'object').columns:
    print (col)
    print(df[col].unique())
    print('--'* 30)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ------------------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ------------------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ------------------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' 'ROU' 'NOR' 'OMN' 'ARG' 'POL' 'DEU'
#  'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST' 'CZE'
#  'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR' 'UKR'
#  'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO' 'ISR'
#  'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM' 'HRV'
#  'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY' 'KWT'
#  'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN' 'SYC'
# ...

# %% [markdown]
# ### Convert columns values
# We can see some confusing values like TA/TO and BB, FB, HB, we will replaced it so it will be easier for us to conduct further analysis.

# %%
df['distribution_channel'].replace('TA/TO', 'Undefined', inplace = True)
df['meal'].replace(['Undefined', 'BB', 'FB', 'HB', 'SC'], ['No Meal', 'Breakfast', 'Full Board', 'Half Board', 'No Meal'], inplace = True)

# %% [markdown]
# ### Create new column

# %%
df['total_night'] = df['stays_in_week_nights'] + df['stays_in_weekend_nights']

# %%
df['arrival_date_month'] = pd.to_datetime(df['arrival_date_month'], format='%B').dt.month

# %%
df['arrival_date'] = pd.to_datetime(dict(year=df.arrival_date_year, month=df.arrival_date_month, day=df.arrival_date_day_of_month))

# %% [markdown]
# ### Drop unnecessary column

# %%
drop_column = ['stays_in_week_nights', 'stays_in_weekend_nights', 'arrival_date_month',
                'arrival_date_year', 'arrival_date_day_of_month', 'arrival_date_week_number']
df.drop(columns= drop_column, inplace = True)

# %%
df.sample(3)
# Out:
#                hotel  is_canceled  lead_time  adults  children  babies  \
# 20705   Resort Hotel            0          3       2         1       0
# 113473    City Hotel            0         18       2         0       0
# 43698     City Hotel            0         83       1         0       0
#
#               meal country market_segment distribution_channel  \
# 20705   Half Board     PRT  Offline TA/TO            Undefined
# 113473   Breakfast     USA      Online TA            Undefined
# 43698    Breakfast     ESP         Groups            Undefined
#
#         is_repeated_guest  previous_cancellations  \
# 20705                   0                       0
# 113473                  0                       0
# 43698                   0                       0
#
#         previous_bookings_not_canceled reserved_room_type assigned_room_type  \
# 20705                                0                  A                  C
# ...

# %% [markdown]
# ###  Descriptive Analysis and Correlations

# %%
df.describe()
# Out:
#         is_canceled     lead_time        adults      children        babies  \
# count  87366.000000  87366.000000  87366.000000  87366.000000  87366.000000
# mean       0.274935     79.915207      1.875936      0.138681      0.010828
# std        0.446484     86.056865      0.626475      0.455942      0.113616
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000     11.000000      2.000000      0.000000      0.000000
# 50%        0.000000     49.000000      2.000000      0.000000      0.000000
# 75%        1.000000    125.000000      2.000000      0.000000      0.000000
# max        1.000000    737.000000     55.000000     10.000000     10.000000
#
#        is_repeated_guest  previous_cancellations  \
# count       87366.000000            87366.000000
# mean            0.039088                0.030424
# std             0.193806                0.369208
# min             0.000000                0.000000
# ...

# %%
df.describe(include = 'object').T
# Out:
#                       count unique         top   freq
# hotel                 87366      2  City Hotel  53422
# meal                  87366      4   Breakfast  67951
# country               87366    177         PRT  27878
# market_segment        87366      7   Online TA  51612
# distribution_channel  87366      4   Undefined  69134
# reserved_room_type    87366     10           A  56530
# assigned_room_type    87366     12           A  46301
# deposit_type          87366      3  No Deposit  86221
# customer_type         87366      4   Transient  71968
# reservation_status    87366      3   Check-Out  63346

# %% [markdown]
# #####   Correlation heatmap
# Type of plot that visualize the strength of relationships between numerical variables.

# %%
plt.rcParams['figure.figsize'] = (10, 6)
sns.heatmap(df.corr(), annot= True, cmap = 'Reds')
plt.suptitle('Correlation between variables')
# Out:
# Text(0.5, 0.98, 'Correlation between variables')

# %% [markdown]
# ## Exploratory Data Analysis & Visualization
#     Understand the context
#         In order to conduct EDA, data analyst will need to be able to come up with right questions to start the process. These questions will help to keep our mind on track and set our expectation during the process.
#
#     Keep in mind that we will need some constrains for our questions because there will be thousands of approach that we can use to come up with the questions. Some constraints can be project goals, business objectives, company values, and client expectations.
#
#     But for this project, we will assume that we have minimal constraints when during the framing question process.

# %%
df.to_csv('final.csv')

# %% [markdown]
# For this dataset, I will choose three main objects (Booking, hotel, customer) to come up with the 15 questions with the help of correlation heatmap and visualizations.

# %% [markdown]
# ## 1. Which hotel's booking mostly by year?

# %%
df['arrival_year'] = df['arrival_date'].dt.year

plt.figure(figsize=(7,6))
sns.countplot(data=df,x='arrival_year',hue=df['hotel'],palette= 'ocean')
plt.xlabel('Arrival year')
plt.ylabel('Count')
plt.title('Year by Booking Hotel')
# Out:
# Text(0.5, 1.0, 'Year by Booking Hotel')

# %%
plt.pie(df['hotel'].value_counts(),labels=['City Hotel', 'Resort Hotel'], autopct="%0.01f%%")
plt.show()

# %% [markdown]
# in 2015 both hotels booking average and almost equal. but 2016, 2017 City hotel more booking than Resort hotel.
# overall City Hotel lead over to Resort Hotel

# %% [markdown]
# ## 2. Which hotel is more booking  canceled?.

# %%
sns.countplot(df['is_canceled'], hue=df['hotel']);
# Out:
# C:\Users\shivh\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# City Hotel has Most No. Of Booking as well as canceled.

# %% [markdown]
# ##  3. What is the big picture of room booking over year and month ?

# %% [markdown]
# #### Room booking over Year

# %%
df['arrival_year'] = df['arrival_date'].dt.year

plt.figure(figsize=(7,6))
sns.countplot(data=df,x='arrival_year',hue='reservation_status',palette= 'ocean')
plt.xlabel('Arrival year')
plt.ylabel('Count of Reservation Booking')
plt.title('Year by Room booking')
plt.show()

# %% [markdown]
# Most rooms are check out while there are still big proportion of rooms are being canceled. The number of of rooms that are booked but the customers were not show up was inconsiderable

# %% [markdown]
# #### Booking by month

# %%
df['arrival_month'] = df['arrival_date'].dt.month

plt.figure(figsize=(7,6))
sns.countplot(data=df,x='arrival_month',hue=df['reservation_status'],palette= ['red', 'blue', 'green'])
plt.xlabel('Arrival month')
plt.ylabel('Count')
plt.title('Year by Booking Hotel')
# Out:
# Text(0.5, 1.0, 'Year by Booking Hotel')

# %% [markdown]
# july & august  are mostly  Check-out and mostly canceled booking too.

# %%
month = df.groupby(['arrival_month'])[['arrival_month']].count()
plt.plot(month['arrival_month'], marker='o')

# %% [markdown]
# in 2015 both hotels booking average and almost equal. but 2016, 2017 City hotel more booking than  Resort hotel

# %% [markdown]
# ## 4. Which Country Has Most No. of Hotels ?

# %%
top10=df[["country","hotel"]].value_counts().head(10).to_frame()
top10=top10.reset_index()
plt.figure(figsize=(15,6))
sns.barplot(x=top10["country"],y=top10[0],data=top10,hue="hotel",palette=['red','blue'],edgecolor="black")
plt.show()

# %% [markdown]
# Portugal Has Most No. Resort Hotels As Well As City Hotels As Compared To Others Countries.

# %% [markdown]
# ## 5.  which month  has more canceled  room booking?

# %%
data=df[df["is_canceled"]==1]
df['arrival_month'] = df['arrival_date'].dt.month
x=data.groupby(["arrival_month","hotel"])["is_canceled"].count()
x=x.reset_index()

plt.figure(figsize=(15,6))
sns.barplot(x=x["arrival_month"],y=x["is_canceled"],data=x,hue="hotel",palette="ocean",edgecolor="black")
plt.title(" Monthly Trend of Booking Cancellation");

# %% [markdown]
# The No. Of Booking Cancellations in City Hotel is Much More Higher Than Resort Hotels.

# %% [markdown]
# ## 6. Average Daily Rate(adr) On nights?

# %%
plt.figure(figsize= (8, 6))
sns.lineplot(x = df['total_night'], y = df['adr'], marker= 'o', hue= df['hotel'])
plt.title("Average price")
# Out:
# Text(0.5, 1.0, 'Average price')

# %% [markdown]
# ## 7.  which room type mostly prefered or asigned to customers?

# %%
plt.figure(figsize=(15,6))
sns.countplot(x=df["assigned_room_type"],palette="ocean",edgecolor="black")
plt.title("Rooms Are Mostly Got Reserved and Assigned To Customers");

# %% [markdown]
# Room (A) - Are Mostly Got Reserved and Assigned To Customers

# %% [markdown]
# ## 8. Which meal mostly prefer by customers?

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="meal",hue="customer_type",data=df,palette=['green', 'blue', 'red', 'yellow'],edgecolor="black")
plt.show()

# %% [markdown]
# Transient customer having breakfast  mostly.

# %% [markdown]
# ## 9. Which Type Of Customer Has No Demand/Changes While Booking the Hotels?

# %%
change_booking = df[df['booking_changes'] == 0]
change_booking = change_booking.groupby(['customer_type'])['booking_changes'].agg(['count'])
change_booking
# Out:
#                  count
# customer_type
# Contract          2753
# Group              435
# Transient        60964
# Transient-Party   7313

# %%
plt.figure(figsize = (8, 6))
sns.barplot(x = change_booking.index, y = 'count', data = change_booking, palette = ['red', 'blue', 'yellow', 'green'])
plt.show()

# %% [markdown]
# Transient customers Have Most No. Changes While Booking the Hotels.
#
# Group customers Have Least Changes While Booking the Hotels.

# %% [markdown]
# ## 10.  Which Rooms has Highest No. of Total Day of Waitings?

# %%
waiting = df.groupby(['reserved_room_type', 'hotel'])['days_in_waiting_list'].agg([ 'sum', 'count']).reset_index()
waiting
# Out:
#    reserved_room_type         hotel    sum  count
# 0                   A    City Hotel  53789  37940
# 1                   A  Resort Hotel   6394  18590
# 2                   B    City Hotel    139    992
# 3                   B  Resort Hotel      0      3
# 4                   C    City Hotel      8     14
# 5                   C  Resort Hotel    135    901
# 6                   D    City Hotel    410  10766
# 7                   D  Resort Hotel   2532   6631
# 8                   E    City Hotel     25   1470
# 9                   E  Resort Hotel   1925   4577
# 10                  F    City Hotel      0   1757
# 11                  F  Resort Hotel      0   1065
# 12                  G    City Hotel    138    479
# 13                  G  Resort Hotel     14   1573
# 14                  H  Resort Hotel      0    596
# 15                  L  Resort Hotel      0      6
# 16                  P    City Hotel      0      4
# 17                  P  Resort Hotel      0      2

# %%
plt.figure(figsize= (8, 6))
sns.barplot(x = waiting['reserved_room_type'], y = waiting['sum'], data = waiting, estimator=sum,palette="ocean",edgecolor="black")
plt.show()

# %% [markdown]
# Rooms-A has Highest No. of Total Day of Waitings.

# %% [markdown]
# ## 11.   What are the most effective booking channels?

# %%
plt.figure(figsize = (8, 6))
df['distribution_channel'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='distribution_channel'>

# %% [markdown]
# after undifined, Direct distribution booking channel are ruled in hotel booking.

# %% [markdown]
# #### Booking channel over time?

# %%
df['month'] = pd.to_datetime(df['arrival_date']).dt.month
distribution_counts = df.groupby(['month', 'distribution_channel']).size().unstack()
plt.figure(figsize= (8, 6))
sns.lineplot(data=distribution_counts)
plt.xlabel('Month')
plt.ylabel('Count of Distribution channel')
plt.show()

# %% [markdown]
# ## 12.  Which Meals prefered by  over time?

# %%
df['month'] = pd.to_datetime(df['arrival_date']).dt.month
meal_count = df.groupby(['month', 'meal']).size().unstack()
plt.figure(figsize= (8, 6))
sns.lineplot(data=meal_count)
plt.xlabel('Month')
plt.ylabel('Count of Distribution channel')
plt.show()

# %% [markdown]
# Breakfast are mostly prefered by customers.

# %% [markdown]
# ## 13. Which hotel has more car parking spaces?

# %%
parking=df.groupby("hotel")["required_car_parking_spaces"].sum()
parking
# Out:
# hotel
# City Hotel      1903
# Resort Hotel    5458
# Name: required_car_parking_spaces, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(x=df["required_car_parking_spaces"],hue="hotel",data=df,palette="ocean",edgecolor="black");

# %% [markdown]
# ## 14.  Which Market Segment Designation Create More Leads To Hotels?

# %%
plt.figure(figsize=(15,6))
sns.countplot(x=df["market_segment"],data=df,hue="hotel",palette="ocean",edgecolor="black")
plt.show()

# %% [markdown]
# Online Travel Agent & Offline Travel Agent Create More Leads To Both The Hotels.

# %% [markdown]
# ## 15. Which  Room  Popular in Reserved  type   In Hotels?

# %%
reserved=df[["reserved_room_type","hotel"]].value_counts().to_frame().reset_index()
plt.figure(figsize=(15,6))
sns.barplot(x="reserved_room_type",y=0,data=reserved,hue="hotel",palette=['red','blue'], edgecolor="black")
plt.show()

# %% [markdown]
# Assigned Rooms No.- (A) Are Frequently Canceled By Customer's .

# %% [markdown]
# ### ----------------------------Analysis Finished--------------------------------
